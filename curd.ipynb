# %%
import pandas as pd

# %%
df = pd.read_csv(r'sales_data_sample.csv', encoding='latin1')

# %%
# Insert new record
new_record = {"ORDERNUMBER": 10100, "QUANTITYORDERED": 10, "PRICEEACH": 100.0, "ORDERLINENUMBER": 1, "SALES": 1000.0}
df = insert_record(df, new_record)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
# 2823        10100               10     100.00                1  1000.00
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
from IPython.display import display
display(read_record(df, "ORDERNUMBER", 10100))
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 578         10100               30     100.00                3  5151.00
# 680         10100               50      67.80                2  3390.00
# 1267        10100               22      86.51                4  1903.22
# 2024        10100               49      34.47                1  1689.03
# 2823        10100               10     100.00                1  1000.00
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 578   1/6/2003 0:00  Shipped     1.0       1.0   2003.0  ...
# 680   1/6/2003 0:00  Shipped     1.0       1.0   2003.0  ...
# 1267  1/6/2003 0:00  Shipped     1.0       1.0   2003.0  ...
# 2024  1/6/2003 0:00  Shipped     1.0       1.0   2003.0  ...
# 2823            NaN      NaN     NaN       NaN      NaN  ...
#
#                   ADDRESSLINE1  ADDRESSLINE2    CITY STATE POSTALCODE COUNTRY  \
# 578   2304 Long Airport Avenue           NaN  Nashua    NH      62005     USA
# ...

# %%
# Update record
df = update_record(df, "ORDERNUMBER", 10100, "PRICEEACH", 120.0)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
# 2823        10100               10     120.00                1  1000.00
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# Delete record
df = delete_record(df, "ORDERNUMBER", 10100)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...
